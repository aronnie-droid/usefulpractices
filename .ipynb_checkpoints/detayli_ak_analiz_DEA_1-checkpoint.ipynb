# %%
import arcpy

# --- Portal bilgileri ---
portal_url = "https://geo.ipa.istanbul/portal/"
username = "harun.karadoru"
password = "harun.karadoru1"

# --- Portal'a giriş ---
arcpy.SignInToPortal(portal_url, username, password)

# --- Feature Service URL (REST, item linki değil) ---
feature_service_url = "https://geo.ipa.istanbul/server/rest/services/Hosted/detayli_ak/FeatureServer/0"

### --- Feature Layer oluştur ---
layer_name = "detayli_ak_lyr"
arcpy.management.MakeFeatureLayer(feature_service_url, layer_name)

# --- Basit kontrol ---
print("Portal:", arcpy.GetActivePortalURL())
print("Layer var mı?:", arcpy.Exists(layer_name))
print("Kayıt sayısı:", arcpy.management.GetCount(layer_name)[0])
# Out:
# Portal: https://geo.ipa.istanbul/portal/
# Layer var mı?: True
# Kayıt sayısı: 174016

# %%
import csv
from collections import Counter

# --- Katmanlar ---
source_layer = "detayli_ak_lyr"
filtered_layer = "detayli_ak_filtered"

# --- CSV yolu ---
csv_path = r"C:\Users\harun.korucu\Desktop\veri_temin_harun\scripts\domains.csv"

# --- CSV'den domain sözlüğü (kod -> açıklama) ---
domain_lookup = {}

with open(csv_path, newline='', encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        domain_lookup[str(row["Kod"])] = row["Adi"]

# --- Anlamlı veri filtresi ---
where_clause = "alt_kullanim IS NOT NULL"

arcpy.management.MakeFeatureLayer(
    source_layer,
    filtered_layer,
    where_clause
)

# --- Toplam kayıt ---
total = int(arcpy.management.GetCount(filtered_layer)[0])

# --- Frekans analizi ---
values = []
with arcpy.da.SearchCursor(filtered_layer, ["alt_kullanim"]) as cursor:
    for row in cursor:
        values.append(str(row[0]))  # kodlar string'e çevrildi

freq = Counter(values)

# --- ÇIKTI ---
print("ANLAMLI KAYIT SAYISI:", total)
print("\nALT_KULLANIM DAĞILIMI (açıklama / adet / %):\n")

for kod, adet in freq.most_common():
    aciklama = domain_lookup.get(kod, f"Bilinmeyen ({kod})")
    print(f"{aciklama} : {adet}  |  %{(adet/total)*100:.2f}")
# Out:
# ANLAMLI KAYIT SAYISI: 102953
#
# ALT_KULLANIM DAĞILIMI (açıklama / adet / %):
#
# KENTSEL KONUT ALANI : 34787  |  %33.79
# TİCARET-KONUT ALANI : 20120  |  %19.54
# REFÜJ/ŞEV-YAMAÇ/ÇAYIR : 12856  |  %12.49
# YAPILAŞMAMIŞ ALAN : 5904  |  %5.73
# TİCARET ALANI : 4709  |  %4.57
# SANAYİ ALANI : 2478  |  %2.41
# PARK : 2361  |  %2.29
# İNŞAAT ALANI : 1661  |  %1.61
# CAMİ/MESCİT ALANI : 1410  |  %1.37
# SANAYİ-TİCARET ALANI : 1149  |  %1.12
# SANAYİ-KONUT ALANI : 907  |  %0.88
# AÇIK OTOPARK : 821  |  %0.80
# SANAYİ-TİCARET-KONUT ALANI : 739  |  %0.72
# ORMAN ALANI : 625  |  %0.61
# KAMU KURUMU (YEREL İDARE) : 603  |  %0.59
# AĞAÇLIK ALAN : 572  |  %0.56
# ANAOKULU ALANI : 562  |  %0.55
# AKARSU/DERE : 538  |  %0.52
# ORGANİZE SANAYİ BÖLGESİ : 530  |  %0.51
# İLKOKUL ALANI : 505  |  %0.49
# LİSE ALANI : 497  |  %0.48
# KAMU KURUMU (MERKEZİ İDARE) : 455  |  %0.44
# ORTAOKUL ALANI : 431  |  %0.42
# DEPOLAMA VE LOJİSTİK TESİS ALANI : 385  |  %0.37
# İKİNCİ BASAMAK SAĞLIK TESİSİ ALANI : 373  |  %0.36
# AKARYAKIT VE SERVİS İSTASYONU ALANI : 363  |  %0.35
# BİRİNCİ BASAMAK SAĞLIK TESİSİ ALANI : 326  |  %0.32
# ÖĞRENCİ YURDU ALANI : 321  |  %0.31
# KÜLTÜREL TESİS ALANI : 319  |  %0.31
# TURİZM ALANI (KONAKLAMA) : 309  |  %0.30
# ÖZEL ÖĞRETİM KURUMU : 268  |  %0.26
# MEZARLIK ALANI : 262  |  %0.25
# KÜÇÜK SANAYİ SİTESİ : 242  |  %0.24
# YAYA BÖLGESİ : 240  |  %0.23
# AÇIK SPOR ALANI : 227  |  %0.22
# ÖZEL EĞİTİM VE REHABİLİTASYON TESİSİ ALANI : 224  |  %0.22
# HAYAT BOYU ÖĞRENME MERKEZİ : 203  |  %0.20
# METRUK/HARABE : 198  |  %0.19
# İLK-ORTAOKUL-LİSE ALANI : 191  |  %0.19
# İLK-ORTAOKUL ALANI : 181  |  %0.18
# SOSYAL TESİS ALANI : 174  |  %0.17
# ARA İSTASYON : 164  |  %0.16
# TARIM ALANI : 152  |  %0.15
# KREŞ : 149  |  %0.14
# KIRSAL KONUT ALANI : 149  |  %0.14
# KAPALI SPOR ALANI : 147  |  %0.14
# MESLEKİ VE TEKNİK LİSE ALANI : 143  |  %0.14
# ÜNİVERSİTE ALANI : 137  |  %0.13
# TİCARET-TURİZM ALANI : 136  |  %0.13
# TRAFO ALANI / İNDİRİCİ MERKEZLER : 120  |  %0.12
# DEMİRYOLU ALANI  : 85  |  %0.08
# MEYDAN : 77  |  %0.07
# KENT PARKI : 72  |  %0.07
# KARMA SPOR KOMPLEKSİ : 69  |  %0.07
# ASKERİ ALAN : 68  |  %0.07
# YAŞLI BAKIMEVİ ALANI : 66  |  %0.06
# RÜZGAR ENERJİSİ SANTRALİ : 60  |  %0.06
# KİLİSE/ŞAPEL ALANI : 59  |  %0.06
# KIYI-KUMUL- KAYALIK ALAN : 57  |  %0.06
# ÜÇÜNCÜ BASAMAK SAĞLIK TESİSİ ALANI : 51  |  %0.05
# TOPLU TAŞIMA GARAJI/ANA DURAK : 50  |  %0.05
# TIR : 48  |  %0.05
# KENTSEL VE BÖLGESEL SPOR ALANI : 46  |  %0.04
# FİDANLIK : 45  |  %0.04
# TİCARET-TURİZM-KONUT ALANI : 45  |  %0.04
# İÇME SUYU TESİSLERİ ALANI (DEPOLAMA-ARITMA-TERFİ MERKEZİ) : 43  |  %0.04
# GÜNÜBİRLİK TESİS ALANI : 43  |  %0.04
# CEMEVİ : 39  |  %0.04
# İSKELE/RIHTIM : 37  |  %0.04
# GERİ DÖNÜŞÜM TESİSİ : 35  |  %0.03
# SERA : 33  |  %0.03
# PAZAR ALANI-OP : 32  |  %0.03
# PARK-YOP : 30  |  %0.03
# KAPALI OTOPARK : 28  |  %0.03
# MADEN SAHASI : 28  |  %0.03
# MİLLET BAHÇESİ : 27  |  %0.03
# KENT ORMANI : 26  |  %0.03
# MESİRE ALANI : 21  |  %0.02
# PAZAR ALANI : 19  |  %0.02
# HAFRİYAT ALANI : 18  |  %0.02
# KUMSAL - PLAJ ALANI : 18  |  %0.02
# GÖL : 16  |  %0.02
# HALK EĞİTİM MERKEZİ : 16  |  %0.02
# KATI ATIK TESİSLERİ ALANI : 15  |  %0.01
# ATIKSU TESİSLERİ ALANI (ARITMA-TERFİ MERKEZİ) : 14  |  %0.01
# MESLEKİ VE TOPLUMSAL ALAN : 13  |  %0.01
# HAVALİMANI/HAVAALANI : 12  |  %0.01
# TEKNOLOJİ GELİŞTİRME BÖLGESİ : 12  |  %0.01
# BARAJ : 12  |  %0.01
# MERA ALANI : 11  |  %0.01
# KENTİÇİ TARIM ALANI : 11  |  %0.01
# MEYDAN-YOP : 10  |  %0.01
# ENERJİ ÜRETİM/DEPOLAMA ALANI : 10  |  %0.01
# TARIM VE HAYVANCILIK TESİS ALANI : 9  |  %0.01
# TEKNE ÇEKEK YERİ/BALIKÇI BARINAĞI : 8  |  %0.01
# PANAYIR - FESTİVAL ALANI : 8  |  %0.01
# DOĞALGAZ İLETİM/DAĞITIM TESİSİ ALANI : 8  |  %0.01
# ELEKTRONİK HABERLEŞME ALTYAPI ALANI : 7  |  %0.01
# SİNAGOG ALANI : 6  |  %0.01
# FUAR-KONGRE ALANI : 5  |  %0.00
# TERMİNAL-OTOGAR : 5  |  %0.00
# ENDÜSTRİ BÖLGESİ : 5  |  %0.00
# YAT LİMANI (MARİNA) : 5  |  %0.00
# HELİPORT : 4  |  %0.00
# ÇOCUK YETİŞTİRME YURDU : 4  |  %0.00
# TABİAT PARKI : 4  |  %0.00
# ARKEOLOJİK ALAN : 4  |  %0.00
# SERBEST BÖLGE : 3  |  %0.00
# REKREASYON ALANI : 3  |  %0.00
# MAKİLİK-FUNDALIK ALAN : 3  |  %0.00
# TRİYAJ ALANI  : 2  |  %0.00
# ARBORETUM : 2  |  %0.00
# HAYVANCILIK ALANI : 1  |  %0.00
# SU KAYNAKLARI TOPLAMA YERİ (KAPTAJ ALANI) : 1  |  %0.00
# JEOTERMAL TESİS ALANI : 1  |  %0.00
# AKARYAKIT ÜRÜNLERİ DEPOLAMA ALANI : 1  |  %0.00
# ANA İSTASYON (GAR) : 1  |  %0.00
# LİMAN : 1  |  %0.00
# TERSANE : 1  |  %0.00
# DENİZ : 1  |  %0.00

# %%
import os
# Kaynak layer (zaten hazır)
source_layer = "detayli_ak_filtered"

# GDB'nin oluşturulacağı klasör
workspace_folder = r"C:\Users\harun.korucu\Desktop\veri_temin_harun"

# GDB adı
gdb_name = "detayli_ak_local.gdb"
gdb_path = os.path.join(workspace_folder, gdb_name)

# Eğer GDB yoksa oluştur
if not arcpy.Exists(gdb_path):
    arcpy.management.CreateFileGDB(workspace_folder, gdb_name)

# Feature class adı
output_fc = os.path.join(gdb_path, "detayli_ak_filtered")

# Feature class olarak kopyala
arcpy.management.CopyFeatures(source_layer, output_fc)

print("Lokal GDB oluşturuldu:", gdb_path)
print("Feature class yazıldı:", output_fc)
print("Kayıt sayısı:", arcpy.management.GetCount(output_fc)[0])
# Out:
# Lokal GDB oluşturuldu: C:\Users\harun.korucu\Desktop\veri_temin_harun\detayli_ak_local.gdb
# Feature class yazıldı: C:\Users\harun.korucu\Desktop\veri_temin_harun\detayli_ak_local.gdb\detayli_ak_filtered
# Kayıt sayısı: 102972
